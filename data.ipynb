# %%
import os

folders = [
"dataset/skin_tone/light",
"dataset/skin_tone/medium",
"dataset/skin_tone/dark",
"dataset/undertone/warm",
"dataset/undertone/cool",
"dataset/undertone/neutral"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(storage={'root_dir': 'dataset/skin_tone/light'})
crawler.crawl(keyword='light skin tone face', max_num=500)

# %%
crawler = BingImageCrawler(storage={'root_dir': 'dataset/skin_tone/medium'})
crawler.crawl(keyword='medium skin tone face', max_num=500)

# %%
crawler = BingImageCrawler(storage={'root_dir': 'dataset/skin_tone/dark'})
crawler.crawl(keyword='dark skin tone face', max_num=500)

# %%
#tones Scraping
crawler = BingImageCrawler(storage={'root_dir': 'dataset/undertone/warm'})
crawler.crawl(keyword='warm undertone skin face', max_num=500)
